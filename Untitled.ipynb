# %%
import pandas as pd
import matplotlib.pyplot as mp
from sklearn.model_selection import train_test_split as TTS,GridSearchCV as GSCV
from sklearn.metrics import classification_report as CR,accuracy_score as AS
from sklearn import set_config
import seaborn as sn
import matplotlib.pyplot as mp
import numpy as np
from sklearn.compose import ColumnTransformer as CT
from sklearn.pipeline import Pipeline as PP
from sklearn.preprocessing import StandardScaler as SS
set_config(display="diagram")

# %%
from sklearn.ensemble import RandomForestClassifier as RFC
from xgboost import XGBClassifier as XGBC
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.naive_bayes import GaussianNB as GNB

# %%
t=pd.read_csv("winequality-red.csv",sep=';')
t
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
t.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
t.duplicated().sum()
# Out:
# 240

# %%
t.drop_duplicates(inplace=True)

# %%
t.duplicated().sum()
# Out:
# 0

# %%
t.shape
# Out:
# (1359, 12)

# %%
f,a=mp.subplots(len(t.columns)-1,figsize=(15,20))
for i,j in enumerate(t.columns):
    if j!="quality":
        sn.boxplot(t[j],ax=a[i])
        mp.tight_layout(pad=0.1)
        a[i].set_xlabel(j,fontsize=16)

# %%
f,a=mp.subplots(len(t.columns)-1,figsize=(15,20))
for i,j in enumerate(t.columns):
    if j!="quality":
        sn.distplot(t[j],ax=a[i])
        mp.tight_layout(pad=0.1)
        a[i].set_xlabel(j,fontsize=16)

# %%
mp.subplots(figsize=(15,8))
k=t.corr()
sn.heatmap(k,annot=True)

# %%
t.drop(["citric acid","free sulfur dioxide"],axis=1,inplace=True)

# %%
t.head()
# Out:
#    fixed acidity  volatile acidity  residual sugar  chlorides  \
# 0            7.4              0.70             1.9      0.076
# 1            7.8              0.88             2.6      0.098
# 2            7.8              0.76             2.3      0.092
# 3           11.2              0.28             1.9      0.075
# 5            7.4              0.66             1.8      0.075
#
#    total sulfur dioxide  density    pH  sulphates  alcohol  quality
# 0                  34.0   0.9978  3.51       0.56      9.4        5
# 1                  67.0   0.9968  3.20       0.68      9.8        5
# 2                  54.0   0.9970  3.26       0.65      9.8        5
# 3                  60.0   0.9980  3.16       0.58      9.8        6
# 5                  40.0   0.9978  3.51       0.56      9.4        5

# %%
t.quality.value_counts().plot.barh();
mp.xlabel("quality",fontsize=15);

# %%
t.quality=np.where(t.quality>=7,1,0)

# %%
x=t.drop("quality",axis=1)
x
# Out:
#       fixed acidity  volatile acidity  residual sugar  chlorides  \
# 0               7.4             0.700             1.9      0.076
# 1               7.8             0.880             2.6      0.098
# 2               7.8             0.760             2.3      0.092
# 3              11.2             0.280             1.9      0.075
# 5               7.4             0.660             1.8      0.075
# ...             ...               ...             ...        ...
# 1593            6.8             0.620             1.9      0.068
# 1594            6.2             0.600             2.0      0.090
# 1595            5.9             0.550             2.2      0.062
# 1597            5.9             0.645             2.0      0.075
# 1598            6.0             0.310             3.6      0.067
#
#       total sulfur dioxide  density    pH  sulphates  alcohol
# 0                     34.0  0.99780  3.51       0.56      9.4
# ...

# %%
y=t.loc[:,"quality"]
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 5       0
#        ..
# 1593    0
# 1594    0
# 1595    0
# 1597    0
# 1598    0
# Name: quality, Length: 1359, dtype: int32

# %%
xta,xte,yta,yte=TTS(x,y,test_size=0.2,random_state=5)

# %%
"RFC ="+str(AS(yte,RFC().fit(xta,yta).predict(xte)))
# Out:
# 'RFC =0.8860294117647058'

# %%
pp=PP(
[
    ("ss",SS()),
    ("knn",KNN()),
])
"KNN ="+str(AS(yte,pp.fit(xta,yta).predict(xte)))
# Out:
# 'KNN =0.8860294117647058'

# %%
pp1=PP(
[
    ("ss",SS()),
    ("svc",SVC()),
])
"SVC ="+str(AS(yte,pp1.fit(xta,yta).predict(xte)))
# Out:
# 'SVC =0.8823529411764706'

# %%
"GNB ="+str(AS(yte,GNB().fit(xta,yta).predict(xte)))
# Out:
# 'GNB =0.875'

# %%
"XGBC ="+str(AS(yte,XGBC().fit(xta,yta).predict(xte)))
# Out:
# 'XGBC =0.875'

# %%
p={
    "criterion":["gini","entropy"],
    "max_depth":np.arange(20),
    "min_samples_split":[2,3,4,5],
    "min_samples_leaf":[1,2,3,4],
    "bootstrap":[True,False]
    
}

# %%
gscv=GSCV(RFC(),param_grid=p,scoring="accuracy",n_jobs=-1,cv=5)

# %%
ppp=PP(
[
    ("SS",SS()),
    ("gscv",gscv)
]
,verbose=True)

# %%
ppp.fit(xta,yta)
# Out:
# [Pipeline] ................ (step 1 of 2) Processing SS, total=   0.0s
# C:\Users\AryanBr0\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 320 fits failed out of a total of 6400.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 160 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AryanBr0\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AryanBr0\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 467, in fit
#     for i, t in enumerate(trees)
# ...

# %%
AS(yte,ppp.predict(xte))
# Out:
# 0.8897058823529411

# %%
ppp.named_steps["gscv"].best_params_
# Out:
# {'bootstrap': True,
#  'criterion': 'entropy',
#  'max_depth': 13,
#  'min_samples_leaf': 4,
#  'min_samples_split': 4}
